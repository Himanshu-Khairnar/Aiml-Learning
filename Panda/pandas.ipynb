# %%
import pandas as pd

# %%
data = pd.DataFrame({
    'A': [1, 2, 3], 
    'B': [4, 5, 6],
    'C': [7, 8, 9]
})
seriesData = pd.Series([10, 11, "Himanshu"], index=['A', 'B', 'C'])

print(seriesData)
# Save DataFrame to a CSV file without the index
# data.to_csv ('output.csv', index=False)
# Out:
# A          10
# B          11
# C    Himanshu
# dtype: object

# %% [markdown]
# ### Reading CSV

# %%
output = pd.read_csv('sales_data_sample.csv',encoding="latin-1")
print(output)
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10159               49     100.00               14  5205.27
# ...           ...              ...        ...              ...      ...
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#             ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# ...

# %% [markdown]
# ### Reading JSON

# %%
js = pd.read_json("sample_Data.json")
print(js)
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
data = ({
    "Name":["Ram","Shyam","Baburao"],
    "Age":[23,44,77],
    "City":["Mumbai","Pune","Nagpur"]
})
df = pd.DataFrame(data)
df.to_csv("output.csv",index=False)
df.to_excel("output.xlsx",index=False)
df.to_json("output.json",index=False)
